# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("hepatitis.csv")

# %%
data.columns=["class","age","sex","steroid", "ANTIVIRALS", "FATIGUE","MALAISE","ANOREXIA","LIVER_big","Liver_firm", "SPLEEN","SPIDERS","ASCITES","VARICES","BILIRUBIN","PHOSPHATE","SGOT","ALBUMIN","PROTIME","HISTOLOGY"]
data.head()
# Out:
#    class  age  sex steroid  ANTIVIRALS FATIGUE MALAISE ANOREXIA LIVER_big  \
# 0      2   50    1       1           2       1       2        2         1
# 1      2   78    1       2           2       1       2        2         2
# 2      2   31    1       ?           1       2       2        2         2
# 3      2   34    1       2           2       2       2        2         2
# 4      2   34    1       2           2       2       2        2         2
#
#   Liver_firm SPLEEN SPIDERS ASCITES VARICES BILIRUBIN PHOSPHATE SGOT ALBUMIN  \
# 0          2      2       2       2       2      0.90       135   42     3.5
# 1          2      2       2       2       2      0.70        96   32     4.0
# 2          2      2       2       2       2      0.70        46   52     4.0
# 3          2      2       2       2       2      1.00         ?  200     4.0
# 4          2      2       2       2       2      0.90        95   28     4.0
#
#   PROTIME  HISTOLOGY
# 0       ?          1
# ...

# %%
#subset
female =data[data["sex"]==2]
male=data[data["sex"]==1]

# %%
female.head()
# Out:
#     class  age  sex steroid  ANTIVIRALS FATIGUE MALAISE ANOREXIA LIVER_big  \
# 19      2   22    2       2           1       1       2        2         2
# 23      2   25    2       1           1       2       2        2         2
# 26      2   58    2       2           2       1       2        2         2
# 31      2   41    2       2           1       1       1        1         2
# 32      2   26    2       1           2       2       2        2         2
#
#    Liver_firm SPLEEN SPIDERS ASCITES VARICES BILIRUBIN PHOSPHATE SGOT ALBUMIN  \
# 19          2      2       2       2       2      0.90        48   20     4.2
# 23          2      2       2       2       2      0.40        45   18     4.3
# 26          1      2       1       2       2      1.40       175   55     2.7
# 31          2      2       2       2       2      0.70        81   53     5.0
# 32          1      2       2       2       2      0.50       135   29     3.8
#
#    PROTIME  HISTOLOGY
# 19      64          1
# ...

# %%
#(b)merge subset
merged_data = pd.concat([male,female])
merged_data.head()
# Out:
#    class  age  sex steroid  ANTIVIRALS FATIGUE MALAISE ANOREXIA LIVER_big  \
# 0      2   50    1       1           2       1       2        2         1
# 1      2   78    1       2           2       1       2        2         2
# 2      2   31    1       ?           1       2       2        2         2
# 3      2   34    1       2           2       2       2        2         2
# 4      2   34    1       2           2       2       2        2         2
#
#   Liver_firm SPLEEN SPIDERS ASCITES VARICES BILIRUBIN PHOSPHATE SGOT ALBUMIN  \
# 0          2      2       2       2       2      0.90       135   42     3.5
# 1          2      2       2       2       2      0.70        96   32     4.0
# 2          2      2       2       2       2      0.70        46   52     4.0
# 3          2      2       2       2       2      1.00         ?  200     4.0
# 4          2      2       2       2       2      0.90        95   28     4.0
#
#   PROTIME  HISTOLOGY
# 0       ?          1
# ...

# %%
sorted_data = data.sort_values(
    by=['age','SGOT','PROTIME'], 
    ascending=[True,False,True]
)

# %%
sorted_data.head()
# Out:
#      class  age  sex steroid  ANTIVIRALS FATIGUE MALAISE ANOREXIA LIVER_big  \
# 109      2    7    1       2           2       2       2        2         2
# 36       2   20    2       1           2       1       1        1         1
# 147      2   20    1       1           2       2       2        2         2
# 120      2   20    1       1           2       1       1        1         2
# 100      2   22    1       2           2       2       2        2         2
#
#     Liver_firm SPLEEN SPIDERS ASCITES VARICES BILIRUBIN PHOSPHATE SGOT  \
# 109          1      1       2       2       2      0.70       256   25
# 36           1      1       1       2       2      2.30       150   68
# 147          ?      2       2       2       2      0.90        89  152
# 120          2      2       1       1       2      1.00       160  118
# 100          2      2       2       2       2      0.70         ?   24
#
#     ALBUMIN PROTIME  HISTOLOGY
# 109     4.2       ?          2
# ...

# %%
#transposed
transposed_data=sorted_data.transpose()
transposed_data.head()
# Out:
#            109 36  147 120 100 19  6   40  35  79   ... 30  83  57  38  15   \
# class        2   2   2   2   2   2   2   2   2   2  ...   1   2   2   2   2
# age          7  20  20  20  22  22  23  23  23  23  ...  62  62  64  65  66
# sex          1   2   1   1   1   2   1   1   1   1  ...   1   2   1   1   1
# steroid      2   1   1   1   2   2   2   2   2   2  ...   1   2   2   2   2
# ANTIVIRALS   2   2   2   2   2   1   2   2   2   2  ...   2   2   1   2   2
#
#            82  114 146 132 1
# class        2   2   1   2   2
# age         67  69  70  72  78
# sex          2   2   1   1   1
# steroid      1   2   1   2   2
# ANTIVIRALS   2   2   2   1   2
#
# [5 rows x 154 columns]

# %%
#long form conversion
data["id"]=data.index
data.head()
# Out:
#    class  age  sex steroid  ANTIVIRALS FATIGUE MALAISE ANOREXIA LIVER_big  \
# 0      2   50    1       1           2       1       2        2         1
# 1      2   78    1       2           2       1       2        2         2
# 2      2   31    1       ?           1       2       2        2         2
# 3      2   34    1       2           2       2       2        2         2
# 4      2   34    1       2           2       2       2        2         2
#
#   Liver_firm  ... SPIDERS ASCITES VARICES BILIRUBIN PHOSPHATE SGOT ALBUMIN  \
# 0          2  ...       2       2       2      0.90       135   42     3.5
# 1          2  ...       2       2       2      0.70        96   32     4.0
# 2          2  ...       2       2       2      0.70        46   52     4.0
# 3          2  ...       2       2       2      1.00         ?  200     4.0
# 4          2  ...       2       2       2      0.90        95   28     4.0
#
#   PROTIME HISTOLOGY  id
# 0       ?         1   0
# ...

# %%
longform = pd.melt(data, id_vars=["id","age","class","sex"])
longform.head()
# Out:
#    id  age  class  sex variable value
# 0   0   50      2    1  steroid     1
# 1   1   78      2    1  steroid     2
# 2   2   31      2    1  steroid     ?
# 3   3   34      2    1  steroid     2
# 4   4   34      2    1  steroid     2

# %%
wideform= longform.pivot(index=["id","age","class","sex"], columns="variable", values="value")
wideform.head()
# Out:
# variable         ALBUMIN ANOREXIA ANTIVIRALS ASCITES BILIRUBIN FATIGUE  \
# id age class sex
# 0  50  2     1       3.5        2          2       2      0.90       1
# 1  78  2     1       4.0        2          2       2      0.70       1
# 2  31  2     1       4.0        2          1       2      0.70       2
# 3  34  2     1       4.0        2          2       2      1.00       2
# 4  34  2     1       4.0        2          2       2      0.90       2
#
# variable         HISTOLOGY LIVER_big Liver_firm MALAISE PHOSPHATE PROTIME  \
# id age class sex
# 0  50  2     1           1         1          2       2       135       ?
# 1  78  2     1           1         2          2       2        96       ?
# 2  31  2     1           1         2          2       2        46      80
# 3  34  2     1           1         2          2       2         ?       ?
# 4  34  2     1           1         2          2       2        95      75
#
# variable         SGOT SPIDERS SPLEEN VARICES steroid
# ...

# %%
#data cleaning
print(data.isnull().sum())
# Out:
# class         0
# age           0
# sex           0
# steroid       0
# ANTIVIRALS    0
# FATIGUE       0
# MALAISE       0
# ANOREXIA      0
# LIVER_big     0
# Liver_firm    0
# SPLEEN        0
# SPIDERS       0
# ASCITES       0
# VARICES       0
# BILIRUBIN     0
# PHOSPHATE     0
# SGOT          0
# ALBUMIN       0
# PROTIME       0
# HISTOLOGY     0
# id            0
# dtype: int64

# %%
data.replace("?",np.nan,inplace=True)
data.head()
# Out:
#    class  age  sex steroid  ANTIVIRALS FATIGUE MALAISE ANOREXIA LIVER_big  \
# 0      2   50    1       1           2       1       2        2         1
# 1      2   78    1       2           2       1       2        2         2
# 2      2   31    1     NaN           1       2       2        2         2
# 3      2   34    1       2           2       2       2        2         2
# 4      2   34    1       2           2       2       2        2         2
#
#   Liver_firm  ... SPIDERS ASCITES VARICES BILIRUBIN PHOSPHATE SGOT ALBUMIN  \
# 0          2  ...       2       2       2      0.90       135   42     3.5
# 1          2  ...       2       2       2      0.70        96   32     4.0
# 2          2  ...       2       2       2      0.70        46   52     4.0
# 3          2  ...       2       2       2      1.00       NaN  200     4.0
# 4          2  ...       2       2       2      0.90        95   28     4.0
#
#   PROTIME HISTOLOGY  id
# 0     NaN         1   0
# ...

# %%
data.dropna(inplace=True)

# %%
for col in data:
    data[col]= pd.to_numeric(data[col])

# %%
data = data[(data[col]>=0).all(axis=1)]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\generic.py:525, in NDFrame._get_axis_number(cls, axis)
#     523             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     524         except KeyError as err:
# --> 525             raise ValueError(
#     526                 f"No axis named {axis} for object type {cls.__name__}"
#
# KeyError: 1
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 data = data[(data[col]>=0).all(axis=1)]
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\util\_decorators.py:336, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     330 if len(args) > num_allow_args:
# ...

# %%
print(data)
# Out:
#      class  age  sex steroid  ANTIVIRALS FATIGUE MALAISE ANOREXIA LIVER_big  \
# 4        2   34    1       2           2       2       2        2         2
# 9        2   39    1       1           1       2       2        2         1
# 10       2   32    1       2           1       1       2        2         2
# 11       2   41    1       2           1       1       2        2         2
# 12       2   30    1       2           2       1       2        2         2
# ..     ...  ...  ...     ...         ...     ...     ...      ...       ...
# 138      2   45    1       2           1       2       2        2         2
# 142      1   49    1       1           2       1       1        2         2
# 144      2   31    1       1           2       1       2        2         2
# 152      2   53    2       1           2       1       2        2         2
# 153      1   43    1       2           2       1       2        2         2
#
# ...

# %%
#outlier
numeric_data = data.select_dtypes(include='number')

Q1 = numeric_data.quantile(0.25)
Q3= numeric_data.quantile(0.75)

IQR= Q3-Q1

lower = Q1 - 1.5*IQR
higher= Q3+1.5*IQR

data_clean =numeric_data[
       ((numeric_data>=lower)& (numeric_data<=higher)).all(axis=1) ]
print (data_clean)
# Out:
#      class  age  sex  ANTIVIRALS  HISTOLOGY   id
# 4        2   34    1           2          1    4
# 9        2   39    1           1          1    9
# 10       2   32    1           1          1   10
# 11       2   41    1           1          1   11
# 12       2   30    1           2          1   12
# 14       2   38    1           2          1   14
# 16       2   40    1           2          1   16
# 17       2   38    1           2          2   17
# 18       2   38    1           1          1   18
# 20       2   27    1           2          1   20
# 21       2   31    1           2          1   21
# 22       2   42    1           2          1   22
# 24       2   27    1           2          1   24
# 27       2   61    1           2          1   27
# 28       2   51    1           1          1   28
# 33       2   35    1           2          1   33
# 35       2   23    1           2          1   35
# 37       2   42    1           2          1   37
# ...

# %%
#stransformation
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

X= data.drop("class",axis=1)
y=data["class"]

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
#regress
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test= train_test_split(X_scaled,y, test_size=0.2, random_state=42)

# %%
lr_model= LogisticRegression()
lr_model.fit(X_train,y_train)
y_pred_lr=lr_model.predict(X_test)
print("accuracy score: ", accuracy_score(y_test,y_pred_lr))
# Out:
# accuracy score:  0.875
